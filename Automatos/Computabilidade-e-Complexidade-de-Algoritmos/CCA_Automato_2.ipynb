# %%
#AUTÔMATO QUE RECONHECE NÚMEROS E REJEITA LETRAS - ex: 10.10

def reconhece(string):
  estado = 'q0'

  for char in string:
    if estado == 'q0':
      if char.isdigit():
        estado = 'q1'
      else:
        estado = 'q_rejeita'
        break
    elif estado == 'q1':
      if char.isdigit():
        estado = 'q1'
      elif char == '.':
        estado = 'q2'
      else:
        estado = 'q_rejeita'
        break
    elif estado == 'q2':
      if char.isdigit():
        estado = 'q3'
      else:
        estado = 'q_rejeita'
        break
    elif estado == 'q3':
      if char.isdigit():
        estado = 'q3'
      else:
        estado = 'q_rejeita'
        break

  if estado in ['q1', 'q3']:
    return string + " ==> é número válido!"
  else:
    return string + " ==> NÃO é número válido!"

# %%
#AUTÔMATO QUE RECONHECE PLACAS DE TRÂNSITO NO MODELO ANTIGO
# q0 - [letra] --> q1 - [letra] --> q2 - [letra] --> q3 - [hifen] --> q4 - [numero] --> q5 - [numero] --> q6 - [numero] --> q7 - [numero]

def reconhece_placa(string):
  estado = 'q0'

  for char in string:
    if estado == 'q0':
      if char.isalpha():
        estado = 'q1'
      else:
        estado = 'q_rejeita'
        break
    elif estado == 'q1':
      if char.isalpha():
        estado = 'q2'
      else:
        estado = 'q_rejeita'
        break
    elif estado == 'q2':
      if char.isalpha():
        estado = 'q3'
      else:
        estado = 'q_rejeita'
        break
    elif estado == 'q3':
      if char == '-':
        estado = 'q4'
      else:
        estado = 'q_rejeita'
        break
    elif estado == 'q4':
      if char.isdigit():
        estado = 'q5'
      else:
        estado = 'q_rejeita'
        break
    elif estado == 'q5':
      if char.isdigit():
        estado = 'q6'
      else:
        estado = 'q_rejeita'
        break
    elif estado == 'q6':
      if char.isdigit():
        estado = 'q7'
      else:
        estado = 'q_rejeita'
        break
    elif estado == 'q7':
      if char.isdigit():
        estado = 'q7'
        break
      else:
        estado = 'q_rejeita'
        break

  if estado in ['q1', 'q7']:
    return string + " ===> PLACA VERIFICADA COM SUCESSO."
  else:
    return string + " ===> ESSA PLACA NÃO PERTENCE AO MODELO SELECIONADO"

# %%
#TESTES

#reconhecer numeros e letras
print(reconhece("123"))
print(reconhece("111111.999999"))

#reconhecer placa de carro antiga
print(reconhece_placa('ABC-DEFG'))
print(reconhece_placa('ABC-1234'))
# Out:
# 123 ==> é número válido!
# 111111.999999 ==> é número válido!
# ABC-DEFG ===> ESSA PLACA NÃO PERTENCE AO MODELO SELECIONADO
# ABC-1234 ===> PLACA VERIFICADA COM SUCESSO.
